# %% [markdown]
# ## String Output Parser

# %%
pip show langchain
# Out:
# Name: langchain
# Version: 1.0.8
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /opt/conda/lib/python3.11/site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by: gpt-researcher, langchain-azure-ai, langchain-tavily
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_core.output_parsers import StrOutputParser

# %%
chat = ChatOpenAI(model = 'gpt-4o-mini', 
                  seed = 365, 
                  temperature = 0, 
                  max_tokens = 100)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 chat = ChatOpenAI(model = 'gpt-4o-mini',
#       2                   seed = 365,
#       3                   temperature = 0,
#       4                   max_tokens = 100)
#
# File /opt/conda/lib/python3.11/site-packages/langchain_core/load/serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File /opt/conda/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:948, in BaseChatOpenAI.validate_environment(self)
#     938         self.http_async_client = httpx.AsyncClient(
#     939             proxy=self.openai_proxy, verify=global_ssl_context
#     940         )
#     941     async_specific = {
#     942         "http_client": self.http_async_client
#     943         or _get_default_async_httpx_client(
#    (...)
#     946         "api_key": async_api_key_value,
#     947     }
# --> 948     self.root_async_client = openai.AsyncOpenAI(
#     949         **client_params,
#     950         **async_specific,  # type: ignore[arg-type]
#     951     )
#     952     self.async_client = self.root_async_client.chat.completions
#     953 return self
#
# File /opt/conda/lib/python3.11/site-packages/openai/_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
message_h = HumanMessage(content = "Can you give me an interesting fact I probably didn't know about?")

# %%
response = chat.invoke([message_h])

# %%
response
# Out:
# AIMessage(content="Sure! Did you know that honey never spoils? Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old and still perfectly edible. Honey's long shelf life is due to its low moisture content and acidic pH, which create an inhospitable environment for bacteria and microorganisms. So, if you have a jar of honey sitting in your pantry, it could potentially last indefinitely!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 86, 'prompt_tokens': 20, 'total_tokens': 106, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b2175cdf48', 'id': 'chatcmpl-DDj5tuxlGLW4rTvhte9uqU5AtlJoC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c9d34-4d51-7e12-b8de-342b9ed6d2b2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 86, 'total_tokens': 106, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
str_output_parser = StrOutputParser()

# %%
response_parsed = str_output_parser.invoke(response)
response_parsed
# Out:
# "Sure! Did you know that honey never spoils? Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old and still perfectly edible. Honey's long shelf life is due to its low moisture content and acidic pH, which create an inhospitable environment for bacteria and microorganisms. So, if you have a jar of honey sitting in your pantry, it could potentially last indefinitely!"

# %% [markdown]
# ## from langchain_core.output_parsers import CommaSeparatedListOutputParser

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser

message_h = HumanMessage(content = f''' I've recently adopted a dog. Could you suggest some dog names? 

{CommaSeparatedListOutputParser().get_format_instructions()}
''')

# %%
print(message_h.content)
# Out:
#  I've recently adopted a dog. Could you suggest some dog names?
#
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %%
response = chat.invoke([message_h])
print(response.content)
# Out:
# Max, Bella, Charlie, Luna, Rocky, Daisy, Cooper, Sadie, Buddy, Molly, Duke, Ruby, Oliver, Chloe, Bear, Zoe, Finn, Lily, Tucker, Nala

# %%
list_output_parser = CommaSeparatedListOutputParser()

# %%
response_parsed = list_output_parser.invoke(response)

# %%
response_parsed
# Out:
# ['Max',
#  'Bella',
#  'Charlie',
#  'Luna',
#  'Rocky',
#  'Daisy',
#  'Cooper',
#  'Sadie',
#  'Buddy',
#  'Molly',
#  'Duke',
#  'Ruby',
#  'Oliver',
#  'Chloe',
#  'Bear',
#  'Zoe',
#  'Finn',
#  'Lily',
#  'Tucker',
#  'Nala']

# %%
print(list_output_parser.get_format_instructions())
# Out:
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`
